# %%
import xml.etree.ElementTree as ET
import numpy as np
import glob
import cv2
import os.path
import matplotlib.pyplot as plt
import scipy.interpolate
import pdb
import re

# %%
# Sort lines into two groups: full lines and interlinear insertions
def sort_lines(baselines):
    # Look at first x coordinate of each baseline to distinguish
    first_xs = [l.T[0][0] for l in baselines]
    x_diffs = np.diff(first_xs)
    
    # Hardcoding the threshold for an interlinear insertion at a difference of 100 pixels
    # TODO: Replace with some per-document computed quantity
    # NOTE: This method may not properly classify multiple insertions in a single line, or insertions too close to the beginning of a line, and if there is an insertion into the first line of a case, as in JUST1-633m48d, it will declare that a full line.
    full_line_indices = []
    threshold = 100
    full_line_indices.append(0)
    for diff_index, diff in enumerate(x_diffs):
        if diff < threshold:
            full_line_indices.append(diff_index+1)
    
    # Return indices of baselines that fall into each category
    return full_line_indices

# %%
def get_line_spacing(baselines):
    #print(baselines)
    center_x = np.median([(l.T[0][0] + l.T[0][-1])/2 for l in baselines])
    
    center_ys = []
    for line in baselines:
        xs, ys = line.T
        center_ys.append(np.interp(center_x, xs, ys))

    med_spacing = np.median(np.diff(center_ys))
    return int(round(med_spacing))

def get_namespace(element):
    #rint(element.tag)
    m = re.match(r'\{.*\}', element.tag)
    return m.group(0)[1:-1] if m else ''

# %%
def subtract_bkd(image):
    bkd = np.percentile(image, 80, axis=0)
    cols = np.arange(image.shape[1])
    coeffs = np.polyfit(cols, bkd, 2)
    smoothed_bkd = np.polyval(coeffs, cols)
    new_image = np.copy(image) / smoothed_bkd * np.median(smoothed_bkd)
    return new_image

def extract_line_image(image_filename, output_filename, baseline, spacing, scaled_height=128, pad=10):
    baseline = np.unique(baseline, axis=0) #remove repeat points
    lower_spacing = int(round(0.23 * spacing))
    upper_spacing = int(round(0.77 * spacing))
    height = lower_spacing + upper_spacing
    
    image = cv2.imread(image_filename, cv2.IMREAD_GRAYSCALE)
    xs, ys = baseline.T
    
    #Vertical pad everything to make the math easier
    top_pad = np.ones((spacing, image.shape[1])) * np.percentile(image[0:2], 80)
    bot_pad = np.ones((spacing, image.shape[1])) * np.percentile(image[-2:], 80)
    image = np.vstack((top_pad, image, bot_pad))
    ys += spacing
    
    dense_xs = np.arange(max(0, xs.min() - pad), 
                         min(image.shape[1]-1, xs.max() + pad))
    
    rectified = np.zeros((height, len(dense_xs)))
    dense_ys = scipy.interpolate.interp1d(xs, ys, bounds_error=False, kind="linear", fill_value="extrapolate")(dense_xs)
    #print(dense_xs.dtype, image.dtype)
    
    #print(xs, ys)
    
    for i,x in enumerate(dense_xs):
        y_min = int(round(dense_ys[i] - upper_spacing))
        y_max = y_min + height
        rectified[:,i] = image[y_min:y_max, x]

    scaled_width = int(round(scaled_height / height * rectified.shape[1]))
    rectified = subtract_bkd(rectified)
    result = cv2.resize(rectified, (scaled_width, scaled_height), cv2.INTER_CUBIC)
    result = (np.median(result) - result) / (np.percentile(result, 90) - np.percentile(result, 10))
    
    cv2.imwrite(output_filename, 255 * (result - result.min()) / (result.max() - result.min()))
        
    if np.random.randint(100) == 0:
        plt.figure()
        plt.imshow(result)
    np.save(output_filename.replace(".png", ".npy"), result)

# %%
# !cd ../val_data
print(glob.glob("../val_data/*.xml"))
# Out:
# ['../val_data/JUST1-734m4.xml', '../val_data/KB27.359.AALT.4467.xml', '../val_data/CP40-649m116a.xml', '../val_data/JUST1-633m60d.xml', '../val_data/KB27-263m21.xml', '../val_data/KB27-645m22a.xml', '../val_data/KB27.345.aalt.5840.1.xml', '../val_data/CP40-648m81a.xml', '../val_data/JUST1-230m2.xml', '../val_data/JUST1-235m13.xml', '../val_data/JUST1-633m52.xml', '../val_data/KB27.342.DORSES.0414.thresk.xml', '../val_data/JUST1-633m5a.xml', '../val_data/CP40-58m14b.xml', '../val_data/CP40-236m280.xml', '../val_data/KB27.345.aalt.5840.2.xml', '../val_data/JUST1-734m17da.xml', '../val_data/kb27.344.aalt.8774.xml', '../val_data/JUST1-734m24d.xml', '../val_data/kb27.352.aalt.2707.xml']

# %%
# !cd ../val_data/

for filename in glob.glob("*.xml"):
    baselines = []
    tree = ET.parse(filename)
    root = tree.getroot()
    ns = {"ns": get_namespace(root)}
    ET.register_namespace('', ns['ns'])
    
    image_filename = root.find('ns:Page', ns).get('imageFilename')
    print(image_filename)

    # Extract baselines
    for text_region in root.findall('.//ns:TextRegion', ns):
        for lineno, text_line in enumerate(text_region.findall('.//ns:TextLine', ns)):
            baseline = text_line.find('ns:Baseline', ns).get('points')
            baselines.append(np.array([p.split(",") for p in baseline.split(" ")], dtype=int))

    #First iteration: calculate average line spacing for both types of lines
    full_line_baseline_indices = sort_lines(baselines)
    med_spacing_full_line = get_line_spacing([baselines[index] for index in full_line_baseline_indices])
    # TODO: replace this hardcoded ratio with a per-document computed quantity
    med_spacing_insertions = med_spacing_full_line//2
    
    # Form list of med_spacings that corresponds to the list of baselines
    med_spacings_list = [med_spacing_full_line \
                         if index in full_line_baseline_indices \
                         else med_spacing_insertions \
                         for index, _ in enumerate(baselines)]
    
    #Second iteration: update bounding boxes
    for text_region in root.findall('.//ns:TextRegion', ns):
        for lineno, (text_line, med_spacing) \
                in enumerate( zip(text_region.findall('.//ns:TextLine', ns), med_spacings_list) ):
            baseline = text_line.find('ns:Baseline', ns).get('points')      
            line_im_filename = "line_{}_{}".format(lineno, image_filename)
            line_im_filename, _ = os.path.splitext(line_im_filename)
            line_im_filename += ".png"
            
            #line_im_filename = f"{os.path.splitext(image_filename)[0]}_line_{lineno}.png"
            extract_line_image(image_filename, line_im_filename, baselines[lineno], med_spacing)
# Out:
# kb27.349.aalt.2908.1.jpg
# [ WARN:0@12.587] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# JUST1-734m18d.jpeg
# KB27.333.AALT.0304.jpg
# kb27.356.dorses.8702.jpg
# JUST1-734m14d.jpeg
# JUST1-734m17.jpeg
# JUST1-633m38.jpeg
# JUST1-633m16d.jpeg
# JUST1-734m23d.jpeg
# kb27.344.aalt.8773.2.jpg
# JUST1-734m5.jpeg
# kb27.349.aalt.2908.2.jpg
# CP40-236m283b.jpg
# JUST1-633m80.png
# JUST1-633m45d.jpg
# JUST1-734m14da.jpeg
# JUST1-633m5.jpeg
# kb27.342.aalt.0476.jpg
# JUST1-633m31.jpeg
# KB27.345.aalt.5839.jpg
# KB27.344.AALT.8730.jpg
# JUST1-734m30d.jpeg
# KB27-646m7REXa.jpg
# KB27.344.AALT.8730.2.jpg
# kb27.344.aalt.9237.jpg
# JUST1-734m7d.jpeg
# CP40-236m170.jpg
# CP40-649m103b.jpg
# kb27.345.aalt.5914.jpg
# JUST1-633m11.jpeg
# JUST1-635m95.jpeg
# JUST1-734m11.jpeg
# JUST1-633m9d.jpeg
# JUST1-734m3d.jpeg
# KB27.354.AALT.7628.jpg
# JUST1-734m14.jpeg
# JUST1-635m37.jpeg
# JUST1-633m12d.jpeg
# JUST1-277m15da.jpeg
# CP40-60m3.jpg
# JUST1-734m1.jpeg
# norw5.jpg
# JUST1-633m167d.jpeg
# CP40-69m97Db.jpg
# CP40-236m177.jpg
# kb27.346.aalt.9641.jpg
# kb27.349.aalt.2908.4.jpg
# JUST1-635m12d.jpeg
# CP40-236m313.jpg
# CP40-236m138.jpg
# KB27.344.AALT.8773.jpg
# JUST1-734m5da.jpeg
# CP40-642m439a.jpg
# JUST1-734m3.jpeg
# norw4.jpg
# JUST1-734m3b.jpeg
# JUST1-633m22.jpeg
# CP40-47m19.jpg
# KB27.343.aalt.8003.2.jpg
# norw3.jpg
# JUST1-734m2d.jpeg
# JUST1-492m39Db.jpg
# CP40-649m103a.jpg
# CP40-236m21Db.jpg
# JUST1-633m2d.jpeg
# KB27.376.AALT.3134.jpg
# JUST1-635m6f.png
# JUST1-734m11d.jpeg
# JUST1-734m12d.jpeg
# JUST1-734m8d.jpeg
# kb27.344.aalt.8774.2.jpg
# memb2.jpg
# kb27.361.aalt.5263.jpg
# JUST1-635m35d.jpeg
# CP40-642m439b.jpg
# KB27-646m7REXb.jpg
# KB27.345.dorses.6098.2.jpg
# JUST1-633m58.jpeg
# CP40-648m81b.jpg
# JUST1-734m17a.jpeg
# KB27-645m22b.jpg
# JUST1-734m13d.jpeg
# JUST1-734m6da.jpeg
# JUST1-633m47d.jpeg
# KB27.341.dorses.0316.1.jpg
# CP40-236m131D.jpg
# JUST1-734m10d.jpeg
# KB27.335.AALT.0235.jpg
# kb27.342.aalt.0428.jpg
# CP40-236m268a.jpg
# kb27.368.dorses.9045.jpg
# JUST1-633m120.png
# CP40-69m97Da.jpg
# JUST1-734m4d.jpeg
# CP40.355.AALT.4070.jpg
# /tmp/ipykernel_3633096/1041313283.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# KB27-646m7REXc.jpg
# CP40-236m192.jpg
# JUST1-734m29.jpeg
# JUST1-734m8.jpeg
# KB27.341.dorses.0316.2.jpg
# JUST1-734m5a.jpeg
# JUST1-734m21d.jpeg
# CP40-236m348Db.jpg
# JUST1-633m32.jpeg
# CP40-236m283a.jpg
# JUST1-633m3d.jpeg
# JUST1-734m27.jpeg
# CP40-649m116c.jpg
# JUST1-734m12.jpeg
# JUST1-633m22d.jpeg
# JUST1-635m36d.jpeg
# JUST1-734m10da.jpeg
# KB27.350.AALT.3869.jpg
# kb27.345.aalt.6136.jpg
# CP40-236m268b.jpg
# kb27.343.dorses.8361.jpg
# JUST1-633m21d.jpeg
# norw7.jpg
# KB27-645m22c.jpg
# kb27.346.aalt.9682.jpg
# norw6.jpg
# JUST1-632m3d.jpeg
# CP40-642m439Dc.jpg
# JUST1-635m13f.jpeg
# JUST1-635m6.jpeg
# CP40-649m116b.jpg
# kb27.348.dorses.1576.jpg
# KB27.356.AALT.8740.jpg
# JUST1-734m13.jpeg
# memb1.jpg
# kb27.353.aalt.6447.jpg
# JUST1-734m6d.jpeg
# JUST1-633m38d.jpeg
# kb27.349.aalt.3007.jpg
# CP40-236m266D.jpg
# JUST1-734m18.jpeg
# JUST1-734m7.jpeg
# JUST1-734m15d.jpeg
# norw2.jpg
# JUST1-734m32d.jpeg
# JUST1-734m7a.jpeg
# kb27.343.aalt.8049.jpg
# JUST1-734m4da.jpeg
# norw1.jpg
# kb27.354.aalt.7348.jpg
# CP40-236m180.jpg
# CP40-236m348Da.jpg
# JUST1-820m18.jpeg
# JUST1-633m84d.jpeg
# KB27-645m22d.jpg
# JUST1-492m39Da.jpg
# kb27.349.aalt.2908.3.jpg
# CP40-236m143Da.jpg
# JUST1-734m17d.jpeg
# JUST1-734m2.jpg
# CP40-236m143Db.jpg
# JUST1-635m89.jpeg
# CP40-60m34D.jpg
# JUST1-633m20.jpeg
# KB27.345.dorses.6098.1.jpg
# CP40-236m172.jpg
# KB27.341.AALT.0320.jpg
# JUST1-277m15d.jpeg
# JUST1-734m3a.jpeg
# CP40-236m267D.jpg
# JUST1-734m15a.jpeg
# JUST1-633m48d.jpeg
# JUST1-734m6.jpeg
# KB27.343.aalt.8003.jpg
# CP40-58m14a.jpg
# kb27.342.aalt.0418.jpg
# CP40-236m21Da.jpg
# JUST1-734m5d.jpeg
